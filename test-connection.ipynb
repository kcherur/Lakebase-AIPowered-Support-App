# %%
# %pip list

# %%
# %pip install psycopg2-binary sqlalchemy

# %%
# %restart_python

# %%
# %sql
SELECT version()

# %%
# %pip install sqlalchemy

# %%
import sys
sys.path.insert(0, '/Workspace/Users/k.c.herur@gmail.com/AIPowered-Support-App')

from lakebase import run_query

# Try a simple query
try:
    result = run_query("SELECT version();")
    print("✓ Connection works! Postgres version:", result[0]['version'])
except Exception as e:
    print("✗ Connection failed:", e)
